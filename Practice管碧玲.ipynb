# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)#setting the maximize string show
fb = pd.read_csv('nysu_10902_2019立委_research.csv')
politics = pd.read_csv('9th_legislator_promise.csv')

# %%
fb.head(1)
# Out:
#                             post_id          page_id page_name page_category  \
# 0  244784245612709_2052039854887130  244784245612709       陳學聖          政治人物
#
#                                                                                                                                                                                                                                                                                                                                  message  \
# 0  鑒於中油觀塘案在環評大會迅速通關，原先專案小組考量對藻礁生態有重大影響，建議退回目的事業主管機關，可是此案送進環評大會後，卻投票翻案通過，環保署前副署長詹順貴辭職明志、更在聲明上直言：「既有環評制度的社會信任基礎受到嚴重傷害」。桃園市長鄭文燦選前選後不同臉,更被環團公認「背信忘義」。\n選後中油火速動工三接 ，學聖感於《環評法》改革的聲音未曾中斷，藻礁因三接被開腸破肚案更凸顯許多環評制度現有的缺失和重要性， 今日學聖與潘忠政老師、環境法律人協會張譽尹理事長 、台灣蠻野足心生態協會蔡雅瀅律師、國立台灣大學風險社會與政策研究中心林木興助理研究員、財團法人環境權保障基金會郭鴻儀律師等一同討論《環評法》修正草案，學聖也承諾將於新會期開始送出修法草案。
#
#   story   type  \
# 0   NaN  photo
#
#                                                           permalink  \
# 0  https://www.facebook.com/244784245612709/posts/2052039854887130/
#
#            created_time_gmt  created_time_taipei  ... link_name  \
# 0  2019-01-15T11:00:16+0000  2019-01-15T19:00:16  ...       NaN
#
#   link_description like_count  haha_count  love_count  angry_count  sad_count  \
# 0              NaN        144           0           0            0          0
#
#    wow_count  comment_count  share_count
# 0          0              6            5
#
# [1 rows x 21 columns]

# %%
liu = fb[fb.page_name == "管碧玲 (kuanbiling)"]
liu.head(1)
# Out:
#                                 post_id          page_id         page_name  \
# 10836  112542652141599_2285548514840991  112542652141599  管碧玲 (kuanbiling)
#
#       page_category  \
# 10836          政治人物
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                message  \
# 10836  公務員感動的見證：我們家不搞特權！\n\n我擔任立委14年，老公「無薪階級」11年。他不搞官位、不搞獨董、也不當民間企業的顧問；甚至去找個相關的職業工會補四年的勞保年資，都不願為。\n「君子慎獨」！在沒有人看得到的地方，我們家都自持甚嚴。\n女婿追隨指導教授擔任機要在先，娶我女兒在後，不是因為我的特權，我特別再說明一次。\n9/18媒體炒作女婿特權時，有一個勞保局的官員，9/19就在他參加的群組公開作見證，公務員看多了，他從老公勞保年金怎麼領，清楚看到這是一個不搞特權的家庭！\n他說老公的勞保年金比家庭主婦還少，他感動的為我不搞特權作見證。\n說我搞特權，以訛傳訛持續不斷，今天媒體報導變本加厲，我只好再說明一次，也把老公請出場，對他實在不好意思！\n特別說明：老公是「無薪階級」可不是無業游民喔！他持續作義工，保護台灣文化古蹟，全國第一名（觀光客很喜歡的新北投露天溫泉，是他的傑作），他也是我成為「文資法之母」，最重要的幫手！\n我們家奉獻社會，不搞特權
#
#       story   type  \
# 10836   NaN  photo
#
#                                                               permalink  \
# 10836  https://www.facebook.com/112542652141599/posts/2285548514840991/
#
#                created_time_gmt  created_time_taipei  ... link_name  \
# 10836  2019-01-12T23:00:36+0000  2019-01-13T07:00:36  ...       NaN
#
#       link_description like_count  haha_count  love_count  angry_count  \
# 10836              NaN      11051           0           0            0
#
#        sad_count  wow_count  comment_count  share_count
# 10836          0          0            302          256
#
# [1 rows x 21 columns]

# %%
liu[liu.created_time_taipei == max(liu.created_time_taipei)]
# Out:
#                                 post_id          page_id         page_name  \
# 11322  112542652141599_2950527061676463  112542652141599  管碧玲 (kuanbiling)
#
#       page_category message story   type  \
# 11322          政治人物     NaN   NaN  photo
#
#                                                               permalink  \
# 11322  https://www.facebook.com/112542652141599/posts/2950527061676463/
#
#                created_time_gmt  created_time_taipei  ... link_name  \
# 11322  2020-01-10T14:09:40+0000  2020-01-10T22:09:40  ...       NaN
#
#       link_description like_count  haha_count  love_count  angry_count  \
# 11322              NaN       2963           0           0            0
#
#        sad_count  wow_count  comment_count  share_count
# 11322          0          0             69           27
#
# [1 rows x 21 columns]

# %%
liu[liu.created_time_taipei == min(liu.created_time_taipei)]
# Out:
#                                 post_id          page_id         page_name  \
# 10855  112542652141599_2268074893255020  112542652141599  管碧玲 (kuanbiling)
#
#       page_category               message story   type  \
# 10855          政治人物  201❾     祝福大家\n幸福❾❾！   NaN  photo
#
#                                                               permalink  \
# 10855  https://www.facebook.com/112542652141599/posts/2268074893255020/
#
#                created_time_gmt  created_time_taipei  ... link_name  \
# 10855  2019-01-01T02:41:57+0000  2019-01-01T10:41:57  ...       NaN
#
#       link_description like_count  haha_count  love_count  angry_count  \
# 10855              NaN        165           0           0            0
#
#        sad_count  wow_count  comment_count  share_count
# 10855          0          0             10            1
#
# [1 rows x 21 columns]

# %%
liu['new_date'] = pd.to_datetime(liu['created_time_taipei']).dt.date
liu['month_year'] = pd.to_datetime(liu['new_date']).dt.to_period('M')
liu.head(1)
# Out:
# <ipython-input-17-c4c3de97fa88>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liu['new_date'] = pd.to_datetime(liu['created_time_taipei']).dt.date
# <ipython-input-17-c4c3de97fa88>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liu['month_year'] = pd.to_datetime(liu['new_date']).dt.to_period('M')
#                                 post_id          page_id         page_name  \
# 10836  112542652141599_2285548514840991  112542652141599  管碧玲 (kuanbiling)
#
#       page_category  \
# 10836          政治人物
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                message  \
# 10836  公務員感動的見證：我們家不搞特權！\n\n我擔任立委14年，老公「無薪階級」11年。他不搞官位、不搞獨董、也不當民間企業的顧問；甚至去找個相關的職業工會補四年的勞保年資，都不願為。\n「君子慎獨」！在沒有人看得到的地方，我們家都自持甚嚴。\n女婿追隨指導教授擔任機要在先，娶我女兒在後，不是因為我的特權，我特別再說明一次。\n9/18媒體炒作女婿特權時，有一個勞保局的官員，9/19就在他參加的群組公開作見證，公務員看多了，他從老公勞保年金怎麼領，清楚看到這是一個不搞特權的家庭！\n他說老公的勞保年金比家庭主婦還少，他感動的為我不搞特權作見證。\n說我搞特權，以訛傳訛持續不斷，今天媒體報導變本加厲，我只好再說明一次，也把老公請出場，對他實在不好意思！\n特別說明：老公是「無薪階級」可不是無業游民喔！他持續作義工，保護台灣文化古蹟，全國第一名（觀光客很喜歡的新北投露天溫泉，是他的傑作），他也是我成為「文資法之母」，最重要的幫手！\n我們家奉獻社會，不搞特權
#
#       story   type  \
# 10836   NaN  photo
#
#                                                               permalink  \
# 10836  https://www.facebook.com/112542652141599/posts/2285548514840991/
#
#                created_time_gmt  created_time_taipei  ... like_count  \
# 10836  2019-01-12T23:00:36+0000  2019-01-13T07:00:36  ...      11051
#
#       haha_count love_count  angry_count  sad_count  wow_count  comment_count  \
# 10836          0          0            0          0          0            302
#
#        share_count    new_date  month_year
# 10836          256  2019-01-13     2019-01
#
# [1 rows x 23 columns]

# %%
results = liu.groupby('month_year').sum()
results
# Out:
#                      page_id  like_count  haha_count  love_count  angry_count  \
# month_year
# 2019-01     4276620781380762       21493           0           0            0
# 2019-02     3713907520672767       15170           0           0            0
# 2019-03     3038651607823173       21159           0           0            0
# 2019-04     2701023651398376       10896           0           0            0
# 2019-05     2588480999256777       14984           0           0            0
# 2019-06     4164078129239163       29545           0           0            0
# 2019-07     6189845867787945       90225           0           0            0
# 2019-08     4276620781380762       85301           0           0            0
# 2019-09     5176961998513554       73919           0           0            0
# 2019-10     6189845867787945       82093           0           0            0
# 2019-11     6302388519929544      113115           0           0            0
# 2019-12     7315272389203935       93796           0           0            0
# 2020-01     3488822216389569       35446           0           0            0
#
#             sad_count  wow_count  comment_count  share_count
# month_year
# 2019-01             0          0            857          727
# 2019-02             0          0            990          752
# 2019-03             0          0           2770         1390
# 2019-04             0          0            729          295
# 2019-05             0          0           1399          314
# 2019-06             0          0           1682         1466
# 2019-07             0          0           2971         3994
# 2019-08             0          0           3058         2040
# 2019-09             0          0           3646         2334
# 2019-10             0          0           3434         2768
# 2019-11             0          0           4665         4363
# 2019-12             0          0           5428         5224
# 2020-01             0          0           1187         1524

# %%
results.index.name = 'newhead'
results.reset_index(inplace=True)
results
# Out:
#     newhead           page_id  like_count  haha_count  love_count  \
# 0   2019-01  4276620781380762       21493           0           0
# 1   2019-02  3713907520672767       15170           0           0
# 2   2019-03  3038651607823173       21159           0           0
# 3   2019-04  2701023651398376       10896           0           0
# 4   2019-05  2588480999256777       14984           0           0
# 5   2019-06  4164078129239163       29545           0           0
# 6   2019-07  6189845867787945       90225           0           0
# 7   2019-08  4276620781380762       85301           0           0
# 8   2019-09  5176961998513554       73919           0           0
# 9   2019-10  6189845867787945       82093           0           0
# 10  2019-11  6302388519929544      113115           0           0
# 11  2019-12  7315272389203935       93796           0           0
# 12  2020-01  3488822216389569       35446           0           0
#
#     angry_count  sad_count  wow_count  comment_count  share_count
# 0             0          0          0            857          727
# 1             0          0          0            990          752
# 2             0          0          0           2770         1390
# 3             0          0          0            729          295
# 4             0          0          0           1399          314
# 5             0          0          0           1682         1466
# 6             0          0          0           2971         3994
# 7             0          0          0           3058         2040
# 8             0          0          0           3646         2334
# 9             0          0          0           3434         2768
# 10            0          0          0           4665         4363
# 11            0          0          0           5428         5224
# 12            0          0          0           1187         1524

# %%
results['newhead'].map(str)
# Out:
# 0     2019-01
# 1     2019-02
# 2     2019-03
# 3     2019-04
# 4     2019-05
# 5     2019-06
# 6     2019-07
# 7     2019-08
# 8     2019-09
# 9     2019-10
# 10    2019-11
# 11    2019-12
# 12    2020-01
# Name: newhead, dtype: object

# %%
import matplotlib.pyplot as plt

labels = results['newhead'].map(str)
width = 0.5       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)

ax.bar(labels, results['like_count'], width, label='like_count')
ax.bar(labels, results['share_count'], width, label='share_count', bottom=results['like_count'])
ax.bar(labels, results['comment_count'], width, label='comment_count', bottom=results['share_count']+results['like_count'])

ax.legend()

plt.show()

# %%
November = liu[liu.month_year == "2019-11"]

# %%
results_november = November.groupby('new_date').sum()
results_november
# Out:
#                     page_id  like_count  haha_count  love_count  angry_count  \
# new_date
# 2019-11-01  225085304283198        4830           0           0            0
# 2019-11-02  112542652141599        1725           0           0            0
# 2019-11-04  112542652141599        2278           0           0            0
#
#     angry_count  sad_count  wow_count  comment_count  share_count
# 0             0          0          0            104          511
# 1             0          0          0             38           45
# 2             0          0          0             75           49
# 3             0          0          0            337          188
# 4             0          0          0            552          333
# 5             0          0          0            174          549
# 6             0          0          0            152          192
# 7             0          0          0            133          206
# 8             0          0          0            134           35
# 9             0          0          0            113           71
# 10            0          0          0             96           18
# 11            0          0          0            118           64
# 12            0          0          0            139           26
# 13            0          0          0            538          235
# 14            0          0          0            126           56
# 15            0          0          0             95           47
# 16            0          0          0            362          836
# 17            0          0          0            165          153
# 18            0          0          0             12            5
# 19            0          0          0            197          149
# 20            0          0          0            120          129
# 21            0          0          0             59           47
# 22            0          0          0            121           94
# 23            0          0          0            493          257
# 24            0          0          0            212           68

# %%
labels = [str(i) for i in range(0,25)]

fig,ax= plt.subplots()
fig.set_size_inches(15, 8)

ax.plot(labels, results_november['like_count'], label='like_count')
ax.plot(labels, results_november['share_count'], label='share_count')
ax.plot(labels, results_november['comment_count'], label='comment_count')

ax.legend()

plt.show()

# %%
liu['new_date']=liu['new_date'].map(str)
liu[liu['new_date'] == "2019-11-16"]
# Out:
# <ipython-input-27-c5d5fdea86a7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liu['new_date']=liu['new_date'].map(str)
#                                 post_id          page_id         page_name  \
# 11245  112542652141599_2823264467736057  112542652141599  管碧玲 (kuanbiling)
# 11246  112542652141599_2822953594433811  112542652141599  管碧玲 (kuanbiling)
# 11247  112542652141599_2822720901123747  112542652141599  管碧玲 (kuanbiling)
#
#       page_category  \
# 11245          政治人物
# 11246          政治人物
# 11247          政治人物
#
#                                                                                                                                                                                                                                                                                            message  \
# 11245                                                                                                                                                                                                                                                            人山人海，\n2.1萬人在線上，\n我們的熱情，\n預告光復高雄！
# 11246  昨天記者問我礦業法的問題，\n我告訴他：一直還沒有討論出共識，選舉期間一切都會政治化，討論起來真的很難理性討論，十分困難。\n記者擔心是不是這會期就不修？\n所以問我說：\n那如果這會期不能修，那你們下個會期民進黨還會推嗎？\n我為了回答這個問題，才會去說到下一屆的問題，我說：\n修礦業法是我們一直的方向，如果這會期沒過，下會期如果民進黨過半，一定會全力推動修法。\n\n黃國昌委員不知道我這句話是回答什麼提問，直接操作成民進黨推給下一屆。\n我知道辯解無用，因為沒有修就無法符合大家的期待。\n所以，我願意承受大家的不滿。\n但其實，我是還一直在溝通協調的人呢！
# 11247                                                                                                                                                                                                                                                                                就這樣！\n我們光復高雄！
#
#       story    type  \
# 11245   NaN   photo
# 11246   NaN  status
# 11247   NaN   photo
#
#                                                               permalink  \
# 11245  https://www.facebook.com/112542652141599/posts/2823264467736057/
# 11246  https://www.facebook.com/112542652141599/posts/2822953594433811/
# 11247  https://www.facebook.com/112542652141599/posts/2822720901123747/
#
#                created_time_gmt  created_time_taipei  ... like_count  \
# 11245  2019-11-16T10:13:21+0000  2019-11-16T18:13:21  ...       8008
# 11246  2019-11-16T06:52:19+0000  2019-11-16T14:52:19  ...       1545
# 11247  2019-11-16T04:15:10+0000  2019-11-16T12:15:10  ...       2846
#
#       haha_count love_count  angry_count  sad_count  wow_count  comment_count  \
# 11245          0          0            0          0          0            288
# 11246          0          0            0          0          0            173
# 11247          0          0            0          0          0             77
#
#        share_count    new_date  month_year
# 11245          134  2019-11-16     2019-11
# 11246           39  2019-11-16     2019-11
# 11247           62  2019-11-16     2019-11
#
# [3 rows x 23 columns]
